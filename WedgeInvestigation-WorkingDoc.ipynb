# %% [markdown]
# # Wedge Investigation Working Document

# %% [markdown]
# ## Load Python Packages

# %%
# load Python Packages
import os
import shutil
import io
import csv
import zipfile

# %% [markdown]
# ## Unzip into a Directory

# %%
#Import the Wedge Zip of Zips Small Zipfiles
zip_files = os.listdir("WedgeZipOfZips_Small/holder/")
from zipfile import ZipFile 

#Extract the first zip file from Zip of Zips Small - TEST EXTRACTION
with ZipFile("WedgeZipOfZips_Small/holder/" +zip_files[0], 'r') as zf:
    zf.printdir()
    print('Extracting files...')
    zf.extractall('zip_small-temp')
    print('Done!')
    print(zf.namelist())
# Out:
# File Name                                             Modified             Size
# transArchive_201001_201003_small.csv           2019-09-18 14:47:10      2948918
# Extracting files...
# Done!
# ['transArchive_201001_201003_small.csv']

# %%
for zip_file in zip_files :
    with ZipFile("" +zip_file, 'r') as zf:
        zf.extractall()

# %%
len(zip_files)
# Out:
# 53

# %%
# delete the test folder and files
dir_path = 'zip_small-temp'
shutil.rmtree(dir_path)

# %%
this_zf = zip_files[0]

with ZipFile("WedgeZipOfZips_Small/holder/" + this_zf,'r') as zf :
    zipped_files = zf.namelist()
    
    for file_name in zipped_files :
        input_file = zf.open(file_name,'r')
        input_file = io.TextIOWrapper(input_file,encoding="utf-8")
        
        for idx, line in enumerate(input_file) :
            print(line)
            if idx > 3 :
                break

        input_file.close() # tidy up
# Out:
# "datetime","register_no","emp_no","trans_no","upc","description","trans_type","trans_subtype","trans_status","department","quantity","Scale","cost","unitPrice","total","regPrice","altPrice","tax","taxexempt","foodstamp","wicable","discount","memDiscount","discountable","discounttype","voided","percentDiscount","ItemQtty","volDiscType","volume","VolSpecial","mixMatch","matched","memType","staff","numflag","itemstatus","tenderstatus","charflag","varflag","batchHeaderID","local","organic","display","receipt","card_no","store","branch","match_id","trans_id"
#
# "2010-01-01 09:04:09","5","17","2","0005385200400","Medium Salsa 16oz GMG","I"," "," ","1","1","0","2.6480","2.9900","2.9900","3.9900","0.0000","0","0","1","0","1.0000","0.0000","1","1","0","0.00000000","1","0","0","0.0000","0","0",,"0","2","0","0","0","0",NULL,"0",NULL,,"0","3","1","0","0","1"
#
# ...

# %%
zipped_files
# Out:
# ['transArchive_201701_small.csv']

# %%
for this_zf in zip_files :
    with ZipFile("WedgeZipOfZips_Small/holder/" + this_zf,'r') as zf :
        zipped_files = zf.namelist()

        for file_name in zipped_files :
            print(file_name + "\n")
            input_file = zf.open(file_name,'r')
            input_file = io.TextIOWrapper(input_file,encoding="utf-8")

            for idx, line in enumerate(input_file) :
                print(line)
                if idx > 3 :
                    break

            input_file.close() # tidy up
# Out:
# transArchive_201001_201003_small.csv
#
# "datetime","register_no","emp_no","trans_no","upc","description","trans_type","trans_subtype","trans_status","department","quantity","Scale","cost","unitPrice","total","regPrice","altPrice","tax","taxexempt","foodstamp","wicable","discount","memDiscount","discountable","discounttype","voided","percentDiscount","ItemQtty","volDiscType","volume","VolSpecial","mixMatch","matched","memType","staff","numflag","itemstatus","tenderstatus","charflag","varflag","batchHeaderID","local","organic","display","receipt","card_no","store","branch","match_id","trans_id"
#
# "2010-01-01 09:04:09","5","17","2","0005385200400","Medium Salsa 16oz GMG","I"," "," ","1","1","0","2.6480","2.9900","2.9900","3.9900","0.0000","0","0","1","0","1.0000","0.0000","1","1","0","0.00000000","1","0","0","0.0000","0","0",,"0","2","0","0","0","0",NULL,"0",NULL,,"0","3","1","0","0","1"
#
# ...

# %%
# Check wedge data for delimiters and delimiter type
delimiters = dict() 

# Start by reading in all the files again.

for this_zf in zip_files :
    with ZipFile("WedgeZipOfZips_Small/holder/" + this_zf,'r') as zf :
        zipped_files = zf.namelist()

        for file_name in zipped_files :
            input_file = zf.open(file_name,'r')
            input_file = io.TextIOWrapper(input_file,encoding="utf-8")
            
            dialect = csv.Sniffer().sniff(sample=input_file.readline(),
                                      delimiters=[",",";","\t"])
            
            delimiters[file_name] = dialect.delimiter
            
            #input_file.seek(0)
            
            print(" ".join(["It looks like",
                           file_name,
                           "has delimiter",
                           dialect.delimiter,
                           "."]))

            input_file.close() # tidy up
# Out:
# It looks like transArchive_201001_201003_small.csv has delimiter , .
# It looks like transArchive_201004_201006_small.csv has delimiter , .
# It looks like transArchive_201007_201009_small.csv has delimiter , .
# It looks like transArchive_201010_201012_small.csv has delimiter , .
# It looks like transArchive_201101_201103_small.csv has delimiter , .
# It looks like transArchive_201104_small.csv has delimiter , .
# It looks like transArchive_201105_small.csv has delimiter , .
# It looks like transArchive_201106_small.csv has delimiter , .
# It looks like transArchive_201107_201109_small.csv has delimiter , .
# It looks like transArchive_201110_201112_small.csv has delimiter , .
# It looks like transArchive_201201_201203_inactive_small.csv has delimiter ; .
# It looks like transArchive_201201_201203_small.csv has delimiter , .
# It looks like transArchive_201204_201206_inactive_small.csv has delimiter ; .
# It looks like transArchive_201204_201206_small.csv has delimiter , .
# ...

# %%
#test if statement on the first delimiter
if delimiters['transArchive_201001_201003_small.csv'] == ',':
    print("Comma Delimited")
# Out:
# Comma Delimited

# %%
for this_zf in zip_files :
    with ZipFile("WedgeZipOfZips_Small/holder/" + this_zf,'r') as zf :
        zipped_files = zf.namelist()

        for file_name in zipped_files:
            #print(file_name)
            input_file = zf.open(file_name)
            if delimiters[file_name] == ',':
                for line in input_file.readlines() :
                    line = line.decode("utf-8").strip().split(',')
                       
                    #print(line)
            else:
                for line in input_file.readlines() :
                    line = line.decode("utf-8").strip().split(";")
                
                    #print(line)
                    
            input_file.close()

# %%
#print(input_file.read()[:1000])
            #b"abcde".decode("utf-8")
            #for line in input_file.readlines() :
                #line = line.decode("utf-8").strip().split(dialect.delimiter)

# %%
line
# Out:
# ['2017-01-01 13:50:59',
#  '3',
#  '17',
#  '36',
#  'TAX',
#  'Tax',
#  'A',
#  '',
#  '',
#  '0',
#  '0',
#  '0',
#  '0.0000',
#  '0.0000',
#  '0.0000',
#  '0.0000',
#  '\\N',
#  '0',
#  '0',
#  '0',
#  '0',
#  '0.0000',
#  '0.0000',
#  '0',
#  '0',
#  '0',
#  '\\N',
#  '0',
#  '0',
#  '0',
#  '0.0000',
#  '0',
#  '0',
#  '0',
#  '\\N',
#  '0',
#  '0',
#  '0',
#  '',
#  '\\N',
#  '\\N',
#  '0',
#  '\\N',
#  '',
#  '0',
#  '64562',
#  '1',
#  '0',
#  '0',
#  '11']

# %%
delimiters
# Out:
# {'transArchive_201001_201003_small.csv': ',',
#  'transArchive_201004_201006_small.csv': ',',
#  'transArchive_201007_201009_small.csv': ',',
#  'transArchive_201010_201012_small.csv': ',',
#  'transArchive_201101_201103_small.csv': ',',
#  'transArchive_201104_small.csv': ',',
#  'transArchive_201105_small.csv': ',',
#  'transArchive_201106_small.csv': ',',
#  'transArchive_201107_201109_small.csv': ',',
#  'transArchive_201110_201112_small.csv': ',',
#  'transArchive_201201_201203_inactive_small.csv': ';',
#  'transArchive_201201_201203_small.csv': ',',
#  'transArchive_201204_201206_inactive_small.csv': ';',
#  'transArchive_201204_201206_small.csv': ',',
#  'transArchive_201207_201209_inactive_small.csv': ';',
#  'transArchive_201207_201209_small.csv': ',',
#  'transArchive_201210_201212_inactive_small.csv': ';',
#  'transArchive_201210_201212_small.csv': ',',
#  'transArchive_201301_201303_inactive_small.csv': ';',
#  'transArchive_201301_201303_small.csv': ',',
# ...
